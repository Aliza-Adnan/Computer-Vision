# %%
import cv2
from google.colab import drive
drive.mount('/content/drive')
img = cv2.imread("/content/drive/MyDrive/sample.jpg", 0)
from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F8568A45810>

# %%
import numpy as np
import matplotlib.pyplot as plt
fouriert=np.fft.fft2(img)
ji=np.fft.fftshift(fouriert)
f=np.log(abs(ji))
plt.imshow(f)
u=ji
k=ji
o=ji

# %%
g=ji
l=ji
#g[:,124]=0
#g[:,125]=0
#g[:,126]=0
j=ji.shape[1]//2
for i in range(ji.shape[0]):
  ji[i,j]=0
  ji[j,i]=0

#j=255
#for i in range(256):
#  g[i,j]=0
#  j-=1
res=np.log(abs(ji))
plt.imshow(res)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %%
ig=np.real(np.fft.ifft2(np.fft.ifftshift(ji)))
#igg=np.fft.ifft2(ig)
#iggg=np.real(igg)
plt.imshow(ig)

# %%
def blocking(a,img):
  half=img.shape[0]//2
  print(half)
  full=img.shape[1]
  j=img.shape[0]-1
  if a==1:
    
    #if want to erase horizontal lines then
    for i in range(full):
      img[i,half]=0
      #img[i,j]=0
      #j-=1
    for i in range (img.shape[0]):
      if i ==(256-j):
        img[i,j]=0
        j-=1
  elif a==2:
    #vertical lines
    for i in range(full):
      img[half,i]=0
      #img[i,j]=0
      #j-=1
   # for i in range(img.shape[0]):
     # for j in range(img.shape[1]):
     #   if((i==img.shape[0]-j) or (j==half)):
      #    img[i,j]=0
    for i in range (img.shape[0]):
      if i ==(256-j):
        img[i,j]=0
        j-=1
  elif a==3:
    #diagonal lines
    for i in range(full):
      img[i,half]=0
      img[half,i]=0


  return img

f=blocking(1,o)
ig=np.real(np.fft.ifft2(np.fft.ifftshift(f)))
#igg=np.fft.ifft2(ig)
#iggg=np.real(igg)
plt.imshow(ig)
# Out:
# 128

# %%
fl=blocking(2,u)
igl=np.real(np.fft.ifft2(np.fft.ifftshift(fl)))
#igg=np.fft.ifft2(ig)
#iggg=np.real(igg)
plt.imshow(igl)
# Out:
# 128

# %%
flk=blocking(1,k)
iglk=np.real(np.fft.ifft2(np.fft.ifftshift(flk)))
#igg=np.fft.ifft2(ig)
#iggg=np.real(igg)
plt.imshow(iglk)
# Out:
# 128
